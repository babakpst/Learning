# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.show()
# %matplotlib inline

import seaborn as sns

# %%
df = pd.read_csv('data/olympics.csv',skiprows=4)
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %% [markdown]
# # Plot sports in 1896

# %%
ol1896 = df[df.Edition == 1896]
ol1896.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
ol1896.Sport.value_counts()
# Out:
# Gymnastics       45
# Athletics        37
# Cycling          16
# Shooting         15
# Aquatics         11
# Tennis           10
# Fencing           8
# Weightlifting     6
# Wrestling         3
# Name: Sport, dtype: int64

# %%
ol1896.Sport.value_counts().plot(kind='line', color='red',figsize=(12,4)); # ; to eliminate the type writing

# %%
ol1896.Sport.value_counts().plot(kind='bar', color='green',figsize=(10,4)); # ; to eliminate the type writing

# %%
ol1896.Sport.value_counts().plot(kind='barh', color='yellow'); # ; to eliminate the type writing

# %%
ol1896.Sport.value_counts().plot(kind='pie',colormap = 'Pastel1'); # ; to eliminate the type writing

# %% [markdown]
# # Total number of medals won

# %%
sns.countplot(x='Medal',data=df);

# %% [markdown]
# # number of gold, silver, and bronze medals by gender

# %%
sns.countplot(x='Medal',data=df, hue='Gender');

# %% [markdown]
# # plot number of medals achieved by the Chinese team in beijing 2008
# # change palette

# %%
china =df[(df.NOC == 'CHN') & (df.Edition == 2008) ]
china.head()
# Out:
#           City  Edition     Sport Discipline       Athlete  NOC Gender  \
# 27176  Beijing     2008  Aquatics     Diving   ZHOU, Luxin  CHN    Men
# 27177  Beijing     2008  Aquatics     Diving     WANG, Xin  CHN  Women
# 27178  Beijing     2008  Aquatics     Diving  CHEN, Ruolin  CHN  Women
# 27180  Beijing     2008  Aquatics     Diving      QIN, Kai  CHN    Men
# 27181  Beijing     2008  Aquatics     Diving     HE, Chong  CHN    Men
#
#                 Event Event_gender   Medal
# 27176    10m platform            M  Silver
# 27177    10m platform            W  Bronze
# 27178    10m platform            W    Gold
# 27180  3m springboard            M  Bronze
# 27181  3m springboard            M    Gold

# %%
china.Gender.value_counts().plot(kind='bar'); # using matplotlib

# %%
sns.color_palette() # default color palette
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.color_palette(palette="rocket")
# Out:
# [(0.20973515, 0.09747934, 0.24238489),
#  (0.43860848, 0.12177004, 0.34119475),
#  (0.67824099, 0.09192342, 0.3504148),
#  (0.8833417, 0.19830556, 0.26014181),
#  (0.95381595, 0.46373781, 0.31769923),
#  (0.96516917, 0.70776351, 0.5606593)]

# %%
sns.color_palette("rocket_r") # reverse version
# Out:
# [(0.96516917, 0.70776351, 0.5606593),
#  (0.95381595, 0.46373781, 0.31769923),
#  (0.8833417, 0.19830556, 0.26014181),
#  (0.67824099, 0.09192342, 0.3504148),
#  (0.43860848, 0.12177004, 0.34119475),
#  (0.20973515, 0.09747934, 0.24238489)]

# %%
# current_palette = sns.color_palette("Spectral", as_cmap=True)
current_palette = sns.color_palette(palette="rocket") 
# current_palette = sns.color_palette(palette="rocket", as_cmap=True) 
# current_palette = sns.color_palette()

sns.palplot(current_palette)
plt.show()

# %%
# user defined color map with two colors
myColorPaletteForGoldSilverBronze = ['#FFD700', '#C0C0C0']
sns.color_palette(myColorPaletteForGoldSilverBronze)
# Out:
# [(1.0, 0.8431372549019608, 0.0),
#  (0.7529411764705882, 0.7529411764705882, 0.7529411764705882)]

# %%
sns.countplot(data=china, x='Gender',palette='bwr' ); # using seaborn

# %% [markdown]
# # plot number of Gold, Silver, and Bronze for each gender

# %%
sns.countplot(data=china, x='Medal', hue='Gender', palette='bwr', order=['Gold', 'Silver', 'Bronze'])
# Out:
# <AxesSubplot:xlabel='Medal', ylabel='count'>

# %% [markdown]
# # Head Map

# %%
ol2008 = df[df.Edition==2008]
medals = ol2008.groupby(['NOC','Medal']).size().unstack('Medal',fill_value=0)
final = medals.sort_values(['Gold','Silver','Bronze'],ascending=False)[['Gold','Silver','Bronze']]
final
# Out:
# Medal  Gold  Silver  Bronze
# NOC
# USA     125     109      81
# CHN      74      53      57
# RUS      43      44      56
# GER      42      16      43
# KOR      41      11      26
# ..      ...     ...     ...
# ISR       0       0       1
# MDA       0       0       1
# MRI       0       0       1
# TOG       0       0       1
# VEN       0       0       1
#
# [86 rows x 3 columns]

# %%
sns.heatmap(final);

# %% [markdown]
# # my plot tests

# %%
final = final.transpose()
final
# Out:
# NOC     USA  CHN  RUS  GER  KOR  NED  AUS  GBR  FRA  JPN  ...  VIE  ARM  TPE  \
# Medal                                                     ...
# Gold    125   74   43   42   41   40   31   31   25   23  ...    0    0    0
# Silver  109   53   44   16   11   18   42   25   23   11  ...    1    0    0
# Bronze   81   57   56   43   26    4   76   21   28   17  ...    0    6    4
#
# NOC     AFG  EGY  ISR  MDA  MRI  TOG  VEN
# Medal
# Gold      0    0    0    0    0    0    0
# Silver    0    0    0    0    0    0    0
# Bronze    1    1    1    1    1    1    1
#
# [3 rows x 86 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(final)
# Out:
# <AxesSubplot:xlabel='NOC', ylabel='Medal'>

# %%
# my test
x = [i for i in range(10)]
y = [i**2 for i in x]

plt.figure(figsize=(15,8)) # this is just for the immediate plot, not all plots in the cell
plt.title("squared",fontsize=20)
plt.xlabel("x_label",fontsize=20)
plt.ylabel("y_label",fontsize=20)
sns.barplot(x=x,y=y);
plt.show()
y = [item*2.0 for item in y]
print(y)
sns.barplot(x=x,y=y);
# Out:
# [0.0, 2.0, 8.0, 18.0, 32.0, 50.0, 72.0, 98.0, 128.0, 162.0]

# %% [markdown]
# # Scatterplot by seeborn

# %%
insurance = pd.read_csv('data/insurance.csv')
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.scatterplot(x=insurance['bmi'], y=insurance['charges']);

# %%
sns.regplot(x=insurance['bmi'], y = insurance['charges']);

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x=insurance['bmi'], y = insurance['charges'], hue= insurance['smoker']);

# %%
# different way to define parameters for scatterplot
plt.figure(figsize=(15,8))
sns.scatterplot(data=insurance, x='bmi', y = 'charges', hue='smoker');

# %%
#plt.figure(figsize=(20,20)) # this is not working
sns.lmplot(data=insurance, x='bmi', y = 'charges', hue='smoker',height=8, aspect=1.5);

# %%
sns.lmplot(data=insurance, x='bmi', y = 'charges', hue='smoker', col="smoker", scatter_kws={"edgecolor": "w"}, col_wrap=3, height=8, aspect=1.5);

# %% [markdown]
# # Categorical scatter plot

# %%
plt.figure(figsize=(10,5))
sns.swarmplot(x=insurance['smoker'],y=insurance['charges']);
# Out:
# /home/babak/.local/lib/python3.8/site-packages/seaborn/categorical.py:3544: UserWarning: 12.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/babak/.local/lib/python3.8/site-packages/seaborn/categorical.py:3544: UserWarning: 43.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ==========================
# # Distribution

# %%
iris = pd.read_csv('data/iris.csv', index_col='Id')
print(iris.size)
iris.head()
# Out:
# 750
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                 5.1               3.5                1.4               0.2
# 2                 4.9               3.0                1.4               0.2
# 3                 4.7               3.2                1.3               0.2
# 4                 4.6               3.1                1.5               0.2
# 5                 5.0               3.6                1.4               0.2
#
#         Species
# Id
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# 4   Iris-setosa
# 5   Iris-setosa

# %% [markdown]
# # histogram

# %%
plt.figure(figsize=(10,5))
sns.histplot(iris['Petal Length (cm)']);
print(iris['Petal Length (cm)'].max())
# Out:
# 6.9

# %%
plt.figure(figsize=(10,5))
sns.histplot(iris['Petal Length (cm)'], bins=6);

# %%
plt.figure(figsize=(10,5))
sns.histplot(data = iris, x = 'Petal Length (cm)', bins=6);

# %%
plt.figure(figsize=(10,5))
sns.histplot(data = iris, x = 'Petal Length (cm)', bins=6, hue = 'Species'); 
plt.title("Histogram of Petal Lengths, by Species")
# Out:
# Text(0.5, 1.0, 'Histogram of Petal Lengths, by Species')

# %% [markdown]
# # Kernel Density Estimate (KDE)
#
# This is like a smoothed histogram

# %%
sns.kdeplot(data=iris['Petal Length (cm)'], shade = True);
# Out:
# <ipython-input-18-4636c06e3f87>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=iris['Petal Length (cm)'], shade = True);

# %%
sns.kdeplot(data=iris, x='Petal Length (cm)', hue='Species', shade=True);
plt.title("Distribution of Petal Lengths, by Species");
# Out:
# <ipython-input-29-c650b2efd1b5>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=iris, x='Petal Length (cm)', hue='Species', shade=True);

# %% [markdown]
# # 2D Kernel Density Estimate

# %%
sns.jointplot(x=iris['Petal Length (cm)'], y=iris['Sepal Width (cm)'], kind= "kde");
# the curve on top of the plot is KDE for Petal Length and the curve on the right of the plot is the  KDE for Sepal Width.
