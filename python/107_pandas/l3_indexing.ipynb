# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('data/olympics.csv',skiprows=4)
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
type(df.index) # index has its own type
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
df.index[25] # 24 element in the element
# Out:
# 25

# %%
#df.index[100] = 5 # indices are immutable, we cannot change the index.

# %% [markdown]
# # set_index

# %%
df.set_index('City') # set the index to city
# Out:
#          Edition      Sport       Discipline               Athlete  NOC  \
# City
# Athens      1896   Aquatics         Swimming         HAJOS, Alfred  HUN
# Athens      1896   Aquatics         Swimming      HERSCHMANN, Otto  AUT
# Athens      1896   Aquatics         Swimming     DRIVAS, Dimitrios  GRE
# Athens      1896   Aquatics         Swimming    MALOKINIS, Ioannis  GRE
# Athens      1896   Aquatics         Swimming    CHASAPIS, Spiridon  GRE
# ...          ...        ...              ...                   ...  ...
# Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko  GER
# Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas  LTU
# Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri  ARM
# Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain  CUB
# Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan  RUS
#
#         Gender                       Event Event_gender   Medal
# City
# ...

# %%
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
df.set_index('City', inplace=True) # set the index to city in place
df.head()
# Out:
#         Edition     Sport Discipline             Athlete  NOC Gender  \
# City
# Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                              Event Event_gender   Medal
# City
# Athens              100m freestyle            M    Gold
# Athens              100m freestyle            M  Silver
# Athens  100m freestyle for sailors            M  Bronze
# Athens  100m freestyle for sailors            M    Gold
# Athens  100m freestyle for sailors            M  Silver

# %%
df.reset_index(inplace=True) # this is the opposite of set_index
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
df.NOC.value_counts().to_string()
# Out:
# 'USA    4335\nURS    2049\nGBR    1594\nFRA    1314\nITA    1228\nGER    1211\nAUS    1075\nHUN    1053\nSWE    1021\nGDR     825\nNED     782\nJPN     704\nCHN     679\nRUS     638\nROU     624\nCAN     592\nNOR     537\nPOL     499\nDEN     491\nFRG     490\nKOR     466\nFIN     451\nYUG     435\nBEL     408\nCUB     395\nESP     377\nSUI     376\nBRA     372\nBUL     331\nTCH     329\nEUA     260\nARG     239\nEUN     223\nIND     178\nNZL     164\nUKR     148\nAUT     146\nGRE     145\nPAK     121\nJAM     102\nRSA      97\nBLR      92\nNGR      84\nTUR      82\nKEN      81\nMEX      80\nCRO      79\nURU      76\nPRK      52\nLTU      50\nZZX      48\nIRI      48\nTPE      42\nCZE      41\nKAZ      39\nETH      38\nEST      37\nINA      35\nCHI      33\nPOR      31\nSVK      29\nANZ      29\nEGY      24\nIRL      24\nZIM      23\nBAH      23\nCMR      22\nTHA      21\nSLO      21\nMAR      21\nTRI      20\nMGL      19\nGEO      18\nPAR      17\nRU1      17\nISL      17\nUZB      
# ...

# %% [markdown]
# # sort index
# Allows all items to be sorted by that index

# %%
df.set_index('NOC', inplace=True) # set the index to city in place
df.head()
# Out:
#        City  Edition     Sport Discipline             Athlete Gender  \
# NOC
# HUN  Athens     1896  Aquatics   Swimming       HAJOS, Alfred    Men
# AUT  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto    Men
# GRE  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios    Men
# GRE  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis    Men
# GRE  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon    Men
#
#                           Event Event_gender   Medal
# NOC
# HUN              100m freestyle            M    Gold
# AUT              100m freestyle            M  Silver
# GRE  100m freestyle for sailors            M  Bronze
# GRE  100m freestyle for sailors            M    Gold
# GRE  100m freestyle for sailors            M  Silver

# %%
df.loc['IRI']
# Out:
#                       City  Edition          Sport       Discipline  \
# NOC
# IRI                 London     1948  Weightlifting    Weightlifting
# IRI               Helsinki     1952  Weightlifting    Weightlifting
# IRI               Helsinki     1952  Weightlifting    Weightlifting
# IRI               Helsinki     1952      Wrestling  Wrestling Free.
# IRI               Helsinki     1952      Wrestling  Wrestling Free.
# IRI               Helsinki     1952      Wrestling  Wrestling Free.
# IRI               Helsinki     1952      Wrestling  Wrestling Free.
# IRI               Helsinki     1952      Wrestling  Wrestling Free.
# IRI  Melbourne / Stockholm     1956  Weightlifting    Weightlifting
# IRI  Melbourne / Stockholm     1956      Wrestling  Wrestling Free.
# IRI  Melbourne / Stockholm     1956      Wrestling  Wrestling Free.
# IRI  Melbourne / Stockholm     1956      Wrestling  Wrestling Free.
# IRI  Melbourne / Stockholm     1956      Wrestling  Wrestling Free.
# ...

# %%
df.sort_index(inplace=True)
df.head()
# Out:
#           City  Edition      Sport Discipline              Athlete Gender  \
# NOC
# AFG    Beijing     2008  Taekwondo  Taekwondo     NIKPAI, Rohullah    Men
# AHO      Seoul     1988    Sailing    Sailing      BOERSMA, Jan D.    Men
# ALG  Barcelona     1992  Athletics  Athletics   BOULMERKA, Hassiba  Women
# ALG    Atlanta     1996     Boxing     Boxing      BAHARI, Mohamed    Men
# ALG    Atlanta     1996  Athletics  Athletics  MORCELI, Nourredine    Men
#
#                    Event Event_gender   Medal
# NOC
# AFG              - 58 kg            M  Bronze
# AHO  board (division II)            M  Silver
# ALG                1500m            W    Gold
# ALG              71-75kg            M  Bronze
# ALG                1500m            M    Gold

# %%
df.sort_index(inplace=True, ascending=False)
df.head()
# Out:
#          City  Edition      Sport Discipline               Athlete Gender  \
# NOC
# ZZX  St Louis     1904    Fencing    Fencing          DIAZ, Manuel    Men
# ZZX     Paris     1900       Polo       Polo  FAUQUET LEMAITRE, A.    Men
# ZZX    Athens     1896     Tennis     Tennis  KASDAGLIS, Dionysios    Men
# ZZX  St Louis     1904  Athletics  Athletics      LIGHTBODY, James    Men
# ZZX  St Louis     1904    Fencing    Fencing          FONST, Ramon    Men
#
#            Event Event_gender   Medal
# NOC
# ZZX    foil team            M    Gold
# ZZX         polo            M  Bronze
# ZZX      doubles            M  Silver
# ZZX  4miles team            M  Silver
# ZZX    foil team            M    Gold

# %%
df.reset_index(inplace=True)

# %% [markdown]
# # loc[]

# %%
df.set_index('Athlete', inplace=True)
df.loc['SAEI, Hadi']
# Out:
#             NOC     City  Edition      Sport Discipline Gender       Event  \
# Athlete
# SAEI, Hadi  IRI  Beijing     2008  Taekwondo  Taekwondo    Men  68 - 80 kg
# SAEI, Hadi  IRI   Athens     2004  Taekwondo  Taekwondo    Men  58 - 68 kg
# SAEI, Hadi  IRI   Sydney     2000  Taekwondo  Taekwondo    Men  58 - 68 kg
#
#            Event_gender   Medal
# Athlete
# SAEI, Hadi            M    Gold
# SAEI, Hadi            M    Gold
# SAEI, Hadi            M  Bronze

# %%
df.reset_index(inplace=True)

# %%
df[df.Athlete=='SAEI, Hadi']
# Out:
#           Athlete  NOC     City  Edition      Sport Discipline Gender  \
# 15742  SAEI, Hadi  IRI  Beijing     2008  Taekwondo  Taekwondo    Men
# 15778  SAEI, Hadi  IRI   Athens     2004  Taekwondo  Taekwondo    Men
# 15779  SAEI, Hadi  IRI   Sydney     2000  Taekwondo  Taekwondo    Men
#
#             Event Event_gender   Medal
# 15742  68 - 80 kg            M    Gold
# 15778  58 - 68 kg            M    Gold
# 15779  58 - 68 kg            M  Bronze

# %% [markdown]
# # iloc[]

# %%
df.iloc[122]
# Out:
# Athlete         PERAZIC, Jasmina
# NOC                          YUG
# City                      Moscow
# Edition                     1980
# Sport                 Basketball
# Discipline            Basketball
# Gender                     Women
# Event                 basketball
# Event_gender                   W
# Medal                     Bronze
# Name: 122, dtype: object

# %%
df.iloc[[12,123,1234]]
# Out:
#                     Athlete  NOC       City  Edition       Sport  Discipline  \
# 12          PREVOST, Hélène  ZZX      Paris     1900      Tennis      Tennis
# 123           PEKIC, Sofija  YUG     Moscow     1980  Basketball  Basketball
# 1234  DAVENPORT, Ira Nelson  USA  Stockholm     1912   Athletics   Athletics
#
#      Gender          Event Event_gender   Medal
# 12    Women  mixed doubles            X  Silver
# 123   Women     basketball            W  Bronze
# 1234    Men           800m            M  Bronze

# %%
df.iloc[10:15]
# Out:
#               Athlete  NOC   City  Edition       Sport  Discipline Gender  \
# 10    NILSSON, August  ZZX  Paris     1900  Tug of War  Tug of War    Men
# 11       AABYE, Edgar  ZZX  Paris     1900  Tug of War  Tug of War    Men
# 12    PREVOST, Hélène  ZZX  Paris     1900      Tennis      Tennis  Women
# 13  ROSENBAUM, Hedwig  ZZX  Paris     1900      Tennis      Tennis  Women
# 14      JONES, Marion  ZZX  Paris     1900      Tennis      Tennis  Women
#
#             Event Event_gender   Medal
# 10     tug of war            M    Gold
# 11     tug of war            M    Gold
# 12  mixed doubles            X  Silver
# 13  mixed doubles            X  Bronze
# 14  mixed doubles            X  Bronze

# %% [markdown]
# # plot number of medals at each olympics

# %%
df.Medal.value_counts()
# Out:
# Gold      9850
# Bronze    9689
# Silver    9677
# Name: Medal, dtype: int64

# %%
 df.Edition.value_counts().sort_index().plot(kind='bar',figsize=(15,5));

# %% [markdown]
# # which countries did not win a medal in 2000? how many countries attended?

# %%
ol2008 =df[df.Edition==2008]
ol2008
# Out:
#                 Athlete  NOC     City  Edition          Sport     Discipline  \
# 66     COVENTRY, Kirsty  ZIM  Beijing     2008       Aquatics       Swimming
# 68     COVENTRY, Kirsty  ZIM  Beijing     2008       Aquatics       Swimming
# 69     COVENTRY, Kirsty  ZIM  Beijing     2008       Aquatics       Swimming
# 70     COVENTRY, Kirsty  ZIM  Beijing     2008       Aquatics       Swimming
# 509     HOANG, Anh Tuan  VIE  Beijing     2008  Weightlifting  Weightlifting
# ...                 ...  ...      ...      ...            ...            ...
# 29142  VUKOJICIC, Paola  ARG  Beijing     2008         Hockey         Hockey
# 29165   LANGE, Santiago  ARG  Beijing     2008        Sailing        Sailing
# 29209    HADDAD, Soraya  ALG  Beijing     2008           Judo           Judo
# 29211   BENIKHLEF, Amar  ALG  Beijing     2008           Judo           Judo
# 29215  NIKPAI, Rohullah  AFG  Beijing     2008      Taekwondo      Taekwondo
#
# ...

# %%
medalist=pd.read_csv('data/SummerOlympicmedallists1896to2008-IOCCOUNTRYCODES.csv')
medalist.head()
# Out:
#            Country Int Olympic Committee code ISO code        Country.1
# 0      Afghanistan                        AFG       AF      Afghanistan
# 1          Albania                        ALB       AL          Albania
# 2          Algeria                        ALG       DZ          Algeria
# 3  American Samoa*                        ASA       AS  American Samoa*
# 4          Andorra                        AND       AD          Andorra

# %%
medalist.shape
# Out:
# (201, 4)

# %%
medalist[medalist['Country'] != medalist['Country.1']] # no diff btw country and country.1
# Out:
# Empty DataFrame
# Columns: [Country, Int Olympic Committee code, ISO code, Country.1]
# Index: []

# %%
medalist.set_index('Int Olympic Committee code', inplace=True)
medalist.head()
# Out:
#                                     Country ISO code        Country.1
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra

# %%
medals_2008 = ol2008.NOC.value_counts()
medals_2008
# Out:
# USA    315
# CHN    184
# AUS    149
# RUS    143
# GER    101
#       ...
# CMR      1
# MDA      1
# SUD      1
# VEN      1
# ECU      1
# Name: NOC, Length: 86, dtype: int64

# %%
medalist['medal_2008'] = medals_2008
medalist.head()
# Out:
#                                     Country ISO code        Country.1  \
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra
#
#                             medal_2008
# Int Olympic Committee code
# AFG                                1.0
# ALB                                NaN
# ALG                                2.0
# ASA                                NaN
# AND                                NaN

# %%
medalist[medalist.medal_2008.isnull()]
# Out:
#                                         Country ISO code            Country.1  \
# Int Olympic Committee code
# ALB                                     Albania       AL              Albania
# ASA                             American Samoa*       AS      American Samoa*
# AND                                     Andorra       AD              Andorra
# ANG                                      Angola       AO               Angola
# ANT                         Antigua and Barbuda       AG  Antigua and Barbuda
# ...                                         ...      ...                  ...
# URU                                     Uruguay       UY              Uruguay
# VAN                                     Vanuatu       VU              Vanuatu
# ISV                             Virgin Islands*       VI      Virgin Islands*
# YEM                                       Yemen       YE                Yemen
# ZAM                                      Zambia       ZM               Zambia
#
# ...
